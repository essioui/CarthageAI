# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../data/processed/household_power_consumption_processed.csv')

# %%
df.head()
# Out:
#      Datetime  Daily_Energy_KWh  Day  Month  Year  DayOfWeek  IsWeekend  tavg  \
# 0  2006-12-16         20.152933   16     12  2006          5          1   6.2
# 1  2006-12-17         56.507667   17     12  2006          6          1   4.4
# 2  2006-12-18         36.730433   18     12  2006          0          0   4.6
# 3  2006-12-19         27.769900   19     12  2006          1          0   2.6
# 4  2006-12-20         37.095800   20     12  2006          2          0   2.9
#
#    tmin  tmax
# 0   4.0   8.5
# 1   1.2   7.9
# 2   3.4   5.9
# 3   0.5   5.1
# 4   0.5   5.6

# %%
df.shape
# Out:
# (1442, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1442 entries, 0 to 1441
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Datetime          1442 non-null   object
#  1   Daily_Energy_KWh  1442 non-null   float64
#  2   Day               1442 non-null   int64
#  3   Month             1442 non-null   int64
#  4   Year              1442 non-null   int64
#  5   DayOfWeek         1442 non-null   int64
#  6   IsWeekend         1442 non-null   int64
#  7   tavg              1442 non-null   float64
#  8   tmin              1442 non-null   float64
#  9   tmax              1442 non-null   float64
# dtypes: float64(4), int64(5), object(1)
# memory usage: 112.8+ KB

# %%
df.isna().sum()
# Out:
# Datetime            0
# Daily_Energy_KWh    0
# Day                 0
# Month               0
# Year                0
# DayOfWeek           0
# IsWeekend           0
# tavg                0
# tmin                0
# tmax                0
# dtype: int64
