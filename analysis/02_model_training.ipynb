# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(
    '../data/processed/household_power_consumption_processed.csv',
    parse_dates=['Datetime'],
    index_col='Datetime'
    )

# %%
df.head()
# Out:
#             Daily_Energy_KWh  Day  Month  Year  DayOfWeek  IsWeekend  tavg  \
# Datetime
# 2006-12-16         20.152933   16     12  2006          5          1   6.2
# 2006-12-17         56.507667   17     12  2006          6          1   4.4
# 2006-12-18         36.730433   18     12  2006          0          0   4.6
# 2006-12-19         27.769900   19     12  2006          1          0   2.6
# 2006-12-20         37.095800   20     12  2006          2          0   2.9
#
#             tmin  tmax
# Datetime
# 2006-12-16   4.0   8.5
# 2006-12-17   1.2   7.9
# 2006-12-18   3.4   5.9
# 2006-12-19   0.5   5.1
# 2006-12-20   0.5   5.6

# %%
df.shape
# Out:
# (1442, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1442 entries, 2006-12-16 to 2010-11-26
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Daily_Energy_KWh  1442 non-null   float64
#  1   Day               1442 non-null   int64
#  2   Month             1442 non-null   int64
#  3   Year              1442 non-null   int64
#  4   DayOfWeek         1442 non-null   int64
#  5   IsWeekend         1442 non-null   int64
#  6   tavg              1442 non-null   float64
#  7   tmin              1442 non-null   float64
#  8   tmax              1442 non-null   float64
# dtypes: float64(4), int64(5)
# memory usage: 112.7 KB

# %%
df.isna().sum()
# Out:
# Daily_Energy_KWh    0
# Day                 0
# Month               0
# Year                0
# DayOfWeek           0
# IsWeekend           0
# tavg                0
# tmin                0
# tmax                0
# dtype: int64

# %%
plt.figure(figsize=(12, 6))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap of Household Power Consumption Features')
plt.show()

# %%
df.corr()
# Out:
#                   Daily_Energy_KWh       Day     Month      Year  DayOfWeek  \
# Daily_Energy_KWh          1.000000 -0.000351 -0.085811 -0.078977   0.153773
# Day                      -0.000351  1.000000  0.020266 -0.028119   0.007933
# Month                    -0.085811  0.020266  1.000000 -0.090679   0.000609
# Year                     -0.078977 -0.028119 -0.090679  1.000000  -0.001535
# DayOfWeek                 0.153773  0.007933  0.000609 -0.001535   1.000000
# IsWeekend                 0.199133  0.006265  0.002759 -0.004659   0.790569
# tavg                     -0.550161 -0.014440  0.160639  0.030087   0.016975
# tmin                     -0.520528 -0.023557  0.192845  0.011172   0.023714
# tmax                     -0.549278 -0.005862  0.130047  0.042758   0.015239
#
#                   IsWeekend      tavg      tmin      tmax
# Daily_Energy_KWh   0.199133 -0.550161 -0.520528 -0.549278
# Day                0.006265 -0.014440 -0.023557 -0.005862
# Month              0.002759  0.160639  0.192845  0.130047
# Year              -0.004659  0.030087  0.011172  0.042758
# DayOfWeek          0.790569  0.016975  0.023714  0.015239
# IsWeekend          1.000000  0.018202  0.021889  0.020913
# tavg               0.018202  1.000000  0.962395  0.982387
# tmin               0.021889  0.962395  1.000000  0.906555
# tmax               0.020913  0.982387  0.906555  1.000000
